# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
churn_data = pd.read_csv('Data/churn_data.csv')
churn_data
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %% [markdown]
# # Data Exploration

# %%
churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %% [markdown]
# No missing or null values to worry about.

# %%
churn_data.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
for col in churn_data.columns:
    print(churn_data[col].value_counts())
# Out:
# WV    106
# MN     84
# NY     83
# AL     80
# OH     78
# OR     78
# WI     78
# WY     77
# VA     77
# CT     74
# ID     73
# MI     73
# VT     73
# UT     72
# TX     72
# IN     71
# KS     70
# MD     70
# NJ     68
# NC     68
# MT     68
# WA     66
# NV     66
# CO     66
# RI     65
# MS     65
# MA     65
# AZ     64
# MO     63
# FL     63
# ME     62
# NM     62
# ND     62
# DE     61
# OK     61
# NE     61
# SC     60
# SD     60
# KY     59
# IL     58
# NH     56
# AR     55
# GA     54
# DC     54
# TN     53
# HI     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: state, dtype: int64
# 105    43
# 87     42
# 93     40
# 101    40
# 90     39
#        ..
# 191     1
# 199     1
# 215     1
# 221     1
# 2       1
# Name: account length, Length: 212, dtype: int64
# 415    1655
# 510     840
# 408     838
# Name: area code, dtype: int64
# 364-9904    1
# 331-7425    1
# 406-4604    1
# 408-1513    1
# 378-4013    1
#            ..
# ...

# %% [markdown]
# I decided to look at specifically the customers who stopped using the service.

# %%
churn_customers = churn_data[churn_data['churn'] == True]
churn_customers
# Out:
#      state  account length  area code phone number international plan  \
# 10      IN              65        415     329-6603                 no
# 15      NY             161        415     351-7269                 no
# 21      CO              77        408     393-7984                 no
# 33      AZ              12        408     360-1596                 no
# 41      MD             135        408     383-6029                yes
# ...    ...             ...        ...          ...                ...
# 3301    CA              84        415     417-1488                 no
# 3304    IL              71        510     330-7137                yes
# 3320    GA             122        510     411-5677                yes
# 3322    MD              62        408     409-1856                 no
# 3323    IN             117        415     362-5899                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
for col in churn_customers.columns:
    print(churn_customers[col].value_counts())
# Out:
# TX    18
# NJ    18
# MD    17
# MI    16
# MN    15
# NY    15
# MS    14
# WA    14
# NV    14
# MT    14
# SC    14
# KS    13
# ME    13
# CT    12
# NC    11
# AR    11
# MA    11
# OR    11
# UT    10
# OH    10
# WV    10
# IN     9
# ID     9
# OK     9
# DE     9
# CA     9
# NH     9
# CO     9
# WY     9
# PA     8
# FL     8
# GA     8
# VT     8
# KY     8
# AL     8
# SD     8
# WI     7
# MO     7
# RI     6
# NM     6
# ND     6
# IL     5
# NE     5
# VA     5
# DC     5
# TN     5
# LA     4
# AZ     4
# IA     3
# HI     3
# AK     3
# Name: state, dtype: int64
# 105    9
# 119    9
# 93     8
# 76     8
# 113    8
#       ..
# 140    1
# 114    1
# 104    1
# 224    1
# 1      1
# Name: account length, Length: 164, dtype: int64
# 415    236
# 510    125
# 408    122
# Name: area code, dtype: int64
# 349-3112    1
# 368-7555    1
# 411-2958    1
# 409-1856    1
# 405-5305    1
#            ..
# 383-6029    1
# 332-5521    1
# 380-2558    1
# 399-5291    1
# ...

# %%
churn_customers.describe()
# Out:
#        account length   area code  number vmail messages  total day minutes  \
# count      483.000000  483.000000             483.000000         483.000000
# mean       102.664596  437.817805               5.115942         206.914079
# std         39.467820   42.792270              11.860138          68.997792
# min          1.000000  408.000000               0.000000           0.000000
# 25%         76.000000  408.000000               0.000000         153.250000
# 50%        103.000000  415.000000               0.000000         217.600000
# 75%        127.000000  510.000000               0.000000         265.950000
# max        225.000000  510.000000              48.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count       483.000000        483.000000         483.000000       483.000000
# mean        101.335404         35.175921         212.410145       100.561077
# ...

# %%
print(churn_data.groupby(['churn']).mean())
# Out:
#        account length   area code  number vmail messages  total day minutes  \
# churn
# False      100.793684  437.074737               8.604561         175.175754
# True       102.664596  437.817805               5.115942         206.914079
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# churn
# False       100.283158         29.780421         199.043298       100.038596
# True        101.335404         35.175921         212.410145       100.561077
#
#        total eve charge  total night minutes  total night calls  \
# churn
# False         16.918909           200.133193         100.058246
# True          18.054969           205.231677         100.399586
#
#        total night charge  total intl minutes  total intl calls  \
# churn
# False            9.006074           10.158877          4.532982
# True             9.235528           10.700000          4.163561
#
#        total intl charge  customer service calls
# churn
# ...

# %%
sns.boxplot(x='churn', y = 'account length', data = churn_data, sym = '')
plt.show()

# %% [markdown]
# No significant difference between customers who didn't churn or did based on account length

# %%
sns.boxplot(x='churn', y = 'customer service calls', data = churn_data, sym = '')
plt.title('Customer Churn vs Customer Service Calls')
plt.xlabel('Churn')
plt.ylabel('Number of Customer Service Calls')
plt.show()

# %% [markdown]
# Significant difference between customer groups based on number of customer service calls. On average, customers who churned made more customer service calls.

# %%
sns.boxplot(x='churn', y = 'total day charge', data = churn_data, sym = '')
plt.title('Customer Churn vs Total Day Charge')
plt.xlabel('Churn')
plt.ylabel('Total Day Charge')
plt.show()

# %% [markdown]
# Customers who churned had a higher day charge on average compared to customers who stayed.

# %%
sns.boxplot(x='churn', y = 'total day minutes', data = churn_data, sym = '')
plt.title('Customer Churn vs Total Day Minutes')
plt.xlabel('Churn')
plt.ylabel('Total Day Minutes')
plt.show()

# %%
sns.boxplot(x='churn', y = 'total eve minutes', data = churn_data, sym = '')
plt.title('Customer Churn vs Total Evening Minutes')
plt.xlabel('Churn')
plt.ylabel('Total Evening Minutes')
plt.show()

# %% [markdown]
# # Class Ratios

# %%
sns.countplot(x='churn', data = churn_data)
# Out:
# <AxesSubplot:xlabel='churn', ylabel='count'>

# %% [markdown]
# The class ratios are highly imbalanced towards non-churned customers. I will need to consider possibly oversampling the churned customers to balance this ratio.
